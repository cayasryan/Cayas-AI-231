# %% [markdown]
# # Math Eval Results for Llama 3.2-1B-Instruct
#
# In this notebook we explore the results generated by our evaluation for the Llama 3.2-1B-Instruct model on the MATH dataset.

# %%
from datasets import load_dataset

math_dataset_test = load_dataset('competition_math', split='test')
math_dataset_test.to_pandas().head()
# Out:
#                                              problem    level     type  \
# 0  How many vertical asymptotes does the graph of...  Level 3  Algebra
# 1  What is the positive difference between $120\%...  Level 1  Algebra
# 2  Find $x$ such that $\lceil x \rceil + x = \dfr...  Level 4  Algebra
# 3                     Evaluate $i^5+i^{-25}+i^{45}$.  Level 5  Algebra
# 4            If $2^8=4^x$, what is the value of $x$?  Level 1  Algebra
#
#                                             solution
# 0  The denominator of the rational function facto...
# 1  One hundred twenty percent of 30 is $120\cdot3...
# 2  First, we note that $x$ must be positive, sinc...
# 3  We have $i^5 = i^4\cdot i = 1\cdot (i) = i$.  ...
# 4  Rewrite $4$ as $2^2$ to find $4^x=2^{2x}$.  Si...

# %%
from huggingface_hub import login
import json

# Load token from config.json
with open("../config.json") as f:
    config = json.load(f)

hf_token = config["hf_token"]
login(hf_token)
eval_dataset_FROM_META = load_dataset("meta-llama/Llama-3.2-1B-Instruct-evals", "Llama-3.2-1B-Instruct-evals__math__details")

eval_dataset_FROM_META_df = eval_dataset_FROM_META['latest'].to_pandas()
eval_dataset_FROM_META_df.head()
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /data/students/ryan/.cache/huggingface/token
# Login successful
#     task_type      task_name subtask_name  \
# 0  Generative  math_chat_new         None
# 1  Generative  math_chat_new         None
# 2  Generative  math_chat_new         None
# 3  Generative  math_chat_new         None
# 4  Generative  math_chat_new         None
#
#                                       input_question input_choice_list  \
# 0  Find the imaginary part of \[(\cos12^\circ+i\s...              None
# 1  What is the least, positive four-digit multipl...              None
# 2  What is $(1 + 2 \cdot 3 \cdot 4 \cdot 5) \div ...              None
# 3  Two ropes, 18 meters in length and 24 meters i...              None
# 4  In the diagram below, lines $k$ and $\ell$ are...              None
#
#                                  input_final_prompts input_correct_responses  \
# 0  [<|start_header_id|>user<|end_header_id|>\n\nS...                     [0]
# 1  [<|start_header_id|>user<|end_header_id|>\n\nS...                  [1001]
# 2  [<|start_header_id|>user<|end_header_id|>\n\nS...                    [11]
# 3  [<|start_header_id|>user<|end_header_id|>\n\nS...                     [6]
# 4  [<|start_header_id|>user<|end_header_id|>\n\nS...                    [60]
#
#                               output_prediction_text output_parsed_answer  \
# 0  [## Step 1: Express the given expression in po...                    0
# 1  [## Step 1: Determine the smallest four-digit ...                 1007
# 2  [## Step 1: Calculate the product inside the p...            21.909...
# 3  [## Step 1: Identify the key constraint\nThe p...                    1
# 4  [## Step 1:  The problem provides a diagram wi...                   30
#
#   output_choice_completions output_choice_negative_log_likelihoods  \
# 0                      None                                   None
# 1                      None                                   None
# 2                      None                                   None
# 3                      None                                   None
# 4                      None                                   None
#
#                                       output_metrics  is_correct  \
# 0  {'correct_format': 1.0, 'em': 1.0, 'em_maj1@1'...        True
# 1  {'correct_format': 1.0, 'em': 0.0, 'em_maj1@1'...       False
# 2  {'correct_format': 1.0, 'em': 0.0, 'em_maj1@1'...       False
# 3  {'correct_format': 1.0, 'em': 0.0, 'em_maj1@1'...       False
# 4  {'correct_format': 1.0, 'em': 0.0, 'em_maj1@1'...       False
#
#                                  input_question_hash  \
# 0  5a2e4b5ae809e4fe13e8e25fedadc00309a38c663a0872...
# 1  05be5a24c13a7f03934ca04c01bd595e757234538b3118...
# 2  fc91c2faca18e68429a3ad12d1edcaf5eaa84183506aaf...
# 3  9e87e5f82a292976ff7a0503c803bb2fcbb026b1954d59...
# 4  30625ff210cf5a08933c65b91f4ff6b36fa1d03087ea1a...
#
#                             input_final_prompts_hash     benchmark_label  \
# 0  [adcde01feac66b5a5a928be8804031ffddcb481ef73e4...  MATH (4-shot, CoT)
# 1  [97745be9a6acd60858e258a46fbd4946e2904dd320c6c...  MATH (4-shot, CoT)
# 2  [2a840b3673983db48b20ed473579b710ad1f111764425...  MATH (4-shot, CoT)
# 3  [c7952d5c97db4006ebe8fba59bf41c9caa6dc35c59590...  MATH (4-shot, CoT)
# 4  [857c3d7d39e2cef68320fb00d5271b66676ba06244744...  MATH (4-shot, CoT)
#
#                                          eval_config
# 0  {'max_gen_len': '5120', 'max_prompt_len': '307...
# 1  {'max_gen_len': '5120', 'max_prompt_len': '307...
# 2  {'max_gen_len': '5120', 'max_prompt_len': '307...
# 3  {'max_gen_len': '5120', 'max_prompt_len': '307...
# 4  {'max_gen_len': '5120', 'max_prompt_len': '307...

# %%
import os 

output_dir = "outputs"

results_0shot_file = os.path.join(output_dir, "results_0shot.json")
with open(results_0shot_file, "r") as f:
   results_0shot = json.load(f)

results_4shot_file = os.path.join(output_dir, "results_4shot.json")
with open(results_4shot_file, "r") as f:
   results_4shot = json.load(f)

# %%
import pandas as pd

# combine personal results with Meta's
overall_results = pd.DataFrame(data={"problem": results_0shot['problem'],
                                     "level": results_0shot['level'],
                                     "type": results_0shot['type'],
                                     "ground_truth": results_0shot['answer'],
                                     "0shot_solution": results_0shot['generated_text'],
                                     "4shot_solution": results_4shot['generated_text'],
                                     "0shot_answer": results_0shot['generated_answer'],
                                     "4shot_answer": results_4shot['generated_answer'],
                                     "0shot_em": results_0shot['exact_match'],
                                     "4shot_em": results_4shot['exact_match'],
                                     }
                                     )

eval_dataset_FROM_META_df_2 = eval_dataset_FROM_META_df[["input_question", "output_prediction_text", "output_parsed_answer", "is_correct"]]
eval_dataset_FROM_META_df_2.loc[:, 'is_correct'] = eval_dataset_FROM_META_df_2['is_correct'].astype(int)
eval_dataset_FROM_META_df_2 = eval_dataset_FROM_META_df_2.rename(columns={"input_question": "problem", "output_prediction_text": "meta_solution", "output_parsed_answer": "meta_answer", "is_correct": "meta_em"})

overall_results = pd.merge(overall_results, eval_dataset_FROM_META_df_2, on="problem")
overall_results = overall_results[["problem", "level", "type", "0shot_solution", "4shot_solution", "meta_solution", "ground_truth", "0shot_answer", "4shot_answer", "meta_answer", "0shot_em", "4shot_em", "meta_em"]]
overall_results.head()
# Out:
# /tmp/ipykernel_3902639/3237092055.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 0 ... 1 1 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   eval_dataset_FROM_META_df_2.loc[:, 'is_correct'] = eval_dataset_FROM_META_df_2['is_correct'].astype(int)
#                                              problem    level     type  \
# 0  How many vertical asymptotes does the graph of...  Level 3  Algebra
# 1  What is the positive difference between $120\%...  Level 1  Algebra
# 2  Find $x$ such that $\lceil x \rceil + x = \dfr...  Level 4  Algebra
# 3                     Evaluate $i^5+i^{-25}+i^{45}$.  Level 5  Algebra
# 4            If $2^8=4^x$, what is the value of $x$?  Level 1  Algebra
#
#                                       0shot_solution  \
# 0  ## Step 1: Factor the denominator\nThe denomin...
# 1  ## Step 1: Calculate 120% of 30\nTo find 120% ...
# 2  ## Step 1: Understand the problem\nWe need to ...
# 3  ## Step 1: Evaluate $i^5$\nSince $i^2 = -1$, w...
# 4  ## Step 1: Express both sides of the equation ...
#
#                                       4shot_solution  \
# 0  ## Step 1: Factor the denominator\nTo find the...
# 1  ## Step 1: Calculate 120% of 30\nTo find 120% ...
# 2  ## Step 1: Understand the problem\nWe are give...
# 3  ## Step 1: Recall the properties of the imagin...
# 4  ## Step 1: Rewrite the equation with the same ...
#
#                                        meta_solution  ground_truth  \
# 0  [## Step 1: Factor the denominator\nTo find th...             2
# 1  [## Step 1: Calculate 120% of 30\nTo find 120%...            10
# 2  [## Step 1: Understand the problem\nWe are giv...  \dfrac{9}{7}
# 3  [## Step 1: Recall the properties of the imagi...             i
# 4  [## Step 1: Rewrite the equation with the same...             4
#
#    0shot_answer       4shot_answer meta_answer  0shot_em  4shot_em  meta_em
# 0            -3                  0           2         0         0        1
# 1            10                 10          10         1         1        1
# 2  \dfrac{2}{7}  \dfrac{23+2f}{14}         1-n         0         0        0
# 3             i                  1           1         1         0        0
# 4             4                  2           2         1         0        0

# %%
# Check values where 0-shot and 4-shot em are different
sum(overall_results['0shot_em'] != overall_results['4shot_em'])
# Out:
# 864

# %%
overall_results['level'].value_counts()
# Out:
# level
# Level 5    1324
# Level 4    1214
# Level 3    1131
# Level 2     894
# Level 1     437
# Name: count, dtype: int64

# %%
overall_results[overall_results['4shot_em'] != overall_results['meta_em']]['level'].value_counts()
# Out:
# level
# Level 3    124
# Level 2    113
# Level 4    112
# Level 5     78
# Level 1     41
# Name: count, dtype: int64

# %%
# percent correct per level
print(overall_results.groupby('level')['0shot_em'].mean())
print(overall_results.groupby('level')['4shot_em'].mean())
print(overall_results.groupby('level')['meta_em'].mean())
# Out:
# level
# Level 1    0.654462
# Level 2    0.476510
# Level 3    0.367816
# Level 4    0.224876
# Level 5    0.117069
# Name: 0shot_em, dtype: float64
# level
# Level 1    0.663616
# Level 2    0.495526
# Level 3    0.359859
# Level 4    0.224053
# Level 5    0.092145
# Name: 4shot_em, dtype: float64
# level
# Level 1    0.661327
# Level 2    0.483221
# Level 3    0.352785
# Level 4    0.222405
# Level 5    0.099698
# Name: meta_em, dtype: float64

# %%
# percent correct per type
print(overall_results.groupby('type')['0shot_em'].mean())
print(overall_results.groupby('type')['4shot_em'].mean())
print(overall_results.groupby('type')['meta_em'].mean())
# Out:
# type
# Algebra                   0.471778
# Counting & Probability    0.259494
# Geometry                  0.267223
# Intermediate Algebra      0.152824
# Number Theory             0.229630
# Prealgebra                0.442021
# Precalculus               0.179487
# Name: 0shot_em, dtype: float64
# type
# Algebra                   0.437237
# Counting & Probability    0.276371
# Geometry                  0.254697
# Intermediate Algebra      0.143965
# Number Theory             0.250000
# Prealgebra                0.448909
# Precalculus               0.194139
# Name: 4shot_em, dtype: float64
# type
# Algebra                   0.442291
# Counting & Probability    0.280591
# Geometry                  0.254697
# Intermediate Algebra      0.140642
# Number Theory             0.233333
# Prealgebra                0.442021
# Precalculus               0.190476
# Name: meta_em, dtype: float64

# %%
overall_results[overall_results['4shot_em'] != overall_results['meta_em']]['type'].value_counts()
# Out:
# type
# Algebra                   124
# Prealgebra                 78
# Intermediate Algebra       75
# Precalculus                56
# Number Theory              49
# Geometry                   44
# Counting & Probability     42
# Name: count, dtype: int64

# %%
# Similarity between 0-shot, 4-shot, and meta scores
similarity_0shot_4shot = sum(overall_results['0shot_em'] == overall_results['4shot_em']) / 5000
similarity_0shot_meta = sum(overall_results['0shot_em'] == overall_results['meta_em']) / 5000
similarity_4shot_meta = sum(overall_results['4shot_em'] == overall_results['meta_em']) / 5000

print(f"Similarity between 0-shot and 4-shot: {similarity_0shot_4shot}")
print(f"Similarity between 0-shot and Meta: {similarity_0shot_meta}")
print(f"Similarity between 4-shot and Meta: {similarity_4shot_meta}")
# Out:
# Similarity between 0-shot and 4-shot: 0.8272
# Similarity between 0-shot and Meta: 0.8128
# Similarity between 4-shot and Meta: 0.9064
