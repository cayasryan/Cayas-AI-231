# %% [markdown]
# # Exploring Meta's Eval Results

# %%
# %pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 13.8 MB/s eta 0:00:00
# Collecting fsspec[http]<=2024.6.1,>=2023.1.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (24.1)
# Requirement already satisfied: numpy>=1.17 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (2.0.2)
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-17.0.0-cp310-cp310-macosx_11_0_arm64.whl (27.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 80.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (6.0.2)
# Collecting multiprocess
#   Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32.2 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (4.66.5)
# Collecting dill<0.3.9,>=0.3.0
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (0.24.6)
# Requirement already satisfied: filelock in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: pandas in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from datasets) (2.2.2)
# Collecting aiohttp
#   Downloading aiohttp-3.10.9-cp310-cp310-macosx_11_0_arm64.whl (391 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.1/391.1 kB 36.7 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.14.0-cp310-cp310-macosx_11_0_arm64.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 10.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 6.5 MB/s eta 0:00:00
# Collecting attrs>=17.3.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 9.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp310-cp310-macosx_11_0_arm64.whl (29 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/cayasryan/Downloads/AI 222 231 Repos/Cayas-AI-231/ai231-venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp310-cp310-macosx_11_0_arm64.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, attrs, async-timeout, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.10.9 aiosignal-1.3.1 async-timeout-4.0.3 attrs-24.2.0 datasets-3.0.1 dill-0.3.8 frozenlist-1.4.1 fsspec-2024.6.1 multidict-6.1.0 multiprocess-0.70.16 propcache-0.2.0 pyarrow-17.0.0 xxhash-3.5.0 yarl-1.14.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

from datasets import load_dataset
from huggingface_hub import login

# %%
# Load token from config.json
with open("config.json") as f:
    config = json.load(f)

hf_token = config["hf_token"]
login(hf_token)
eval_dataset_FROM_META = load_dataset("meta-llama/Llama-3.2-1B-Instruct-evals", "Llama-3.2-1B-Instruct-evals__mgsm__details")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /Users/cayasryan/.cache/huggingface/token
# Login successful
# Generating latest split: 100%|██████████| 2750/2750 [00:00<00:00, 15318.19 examples/s]

# %%
eval_dataset_FROM_META_df = eval_dataset_FROM_META['latest'].to_pandas()
eval_dataset_FROM_META_df.head()
# Out:
#     task_type  task_name subtask_name  \
# 0  Generative  mgsm_chat           te
# 1  Generative  mgsm_chat           bn
# 2  Generative  mgsm_chat           bn
# 3  Generative  mgsm_chat           bn
# 4  Generative  mgsm_chat           bn
#
#                                       input_question input_choice_list  \
# 0  ఆండ్రూ న్యూజెర్సీ నుంచి రోచెస్టర్‌కు ఒక రోడ్డు...              None
# 1  কার্লের প্রিয় খাবার হল চিজ্‌। তিনি এই সপ্তাহে ...              None
# 2  জ্যানেটের কাছে 22টি সবুজ কলম ও 10টি হলুদ কলম আ...              None
# 3  ব্রিনলি মিঃ বার্টের অঙ্কের ক্লাসে আছে। প্রত্যে...              None
# 4  মাইকেল বাইক চালাতে ভালোবাসেন। তিনি এটি এক সপ্ত...              None
#
#                                  input_final_prompts  \
# 0  [<|start_header_id|>user<|end_header_id|>\n\nఈ...
# 1  [<|start_header_id|>user<|end_header_id|>\n\nএ...
# 2  [<|start_header_id|>user<|end_header_id|>\n\nএ...
# 3  [<|start_header_id|>user<|end_header_id|>\n\nএ...
# 4  [<|start_header_id|>user<|end_header_id|>\n\nএ...
#
#                              input_correct_responses  \
# 0  [9, 9., 9.0, 9.0., 9.00, 9.00., 9, 9., 9.0, 9....
# 1  [31, 31., 31.0, 31.0., 31.00, 31.00., 31, 31.,...
# 2  [98, 98., 98.0, 98.0., 98.00, 98.00., 98, 98.,...
# 3  [98, 98., 98.0, 98.0., 98.00, 98.00., 98, 98.,...
# 4  [860, 860., 860.0, 860.0., 860.00, 860.00., 86...
#
#                               output_prediction_text output_parsed_answer  \
# 0  [రోచెస్టర్ నుంచి బస్సు ద్వారా ప్రయాణించడానికి ...                  4.5
# 1  [সপ্তাহে তিনি 2*7=<<2*7=14>>14টি স্যান্ডউইচ খে...                   25
# 2  [জ্যানেটের কাছে সবুজ কলমের মোট সংখ্যা হল 22টি ...                  360
# 3  [প্রথম পাঁচটি পরীক্ষার স্কোর যোগ করলে আমরা পাই...                  353
# 4  [মাইকেল 5 বার বাইক চালান, তাই তিনি 5*25=<<5*25...                  860
#
#   output_choice_completions output_choice_negative_log_likelihoods  \
# 0                      None                                   None
# 1                      None                                   None
# 2                      None                                   None
# 3                      None                                   None
# 4                      None                                   None
#
#                                       output_metrics  is_correct  \
# 0  {'em': 0.0, 'em_maj1@1': 0.0, 'f1': 0.0, 'f1_m...       False
# 1  {'em': 0.0, 'em_maj1@1': 0.0, 'f1': 0.0, 'f1_m...       False
# 2  {'em': 0.0, 'em_maj1@1': 0.0, 'f1': 0.0, 'f1_m...       False
# 3  {'em': 0.0, 'em_maj1@1': 0.0, 'f1': 0.0, 'f1_m...       False
# 4  {'em': 1.0, 'em_maj1@1': 1.0, 'f1': 1.0, 'f1_m...        True
#
#                                  input_question_hash  \
# 0  cd94ca91efc39a41e4c4c4bc0c05402edf876bb9e3b947...
# 1  6704115ad46deece36245043307151bd6fd83e02930329...
# 2  c034cb29e28be89863d8c81696515eb46614beb50893ae...
# 3  0c7da335161864651f040a8c291e0e78071a221800dcd4...
# 4  f11366127c3e5d1b93ddb37334135fca18618c47e5b47e...
#
#                             input_final_prompts_hash benchmark_label  \
# 0  [c08c78b2914e6099ee463c3e4f593bf5017c36c1ed754...            MGSM
# 1  [1aec05a3e1d4a893e3b0d35624fb89159fc1c32561ec8...            MGSM
# 2  [b5dc4fc9106d844acf8f278cb90244e5f226aa9043a2a...            MGSM
# 3  [42d35a0e59b2dce67fa4f109447b0752cd28c92d5e570...            MGSM
# 4  [0540c4c88eef5b44aaa61d9152e58f02465331eca313c...            MGSM
#
#                                          eval_config
# 0  {'max_gen_len': '2048', 'max_prompt_len': '614...
# 1  {'max_gen_len': '2048', 'max_prompt_len': '614...
# 2  {'max_gen_len': '2048', 'max_prompt_len': '614...
# 3  {'max_gen_len': '2048', 'max_prompt_len': '614...
# 4  {'max_gen_len': '2048', 'max_prompt_len': '614...

# %%
# Get accuracy per language then get average accuracy
accuracy_per_language = eval_dataset_FROM_META_df.groupby('subtask_name')['is_correct'].mean()
overall_accuracy = accuracy_per_language.mean()

print("Accuracy per language:")
for key, value in accuracy_per_language.items():
    print(f"{key}: {value}")
print("Overall Accuracy:", overall_accuracy)
# Out:
# Accuracy per language:
# bn: 0.144
# de: 0.272
# en: 0.42
# es: 0.352
# fr: 0.264
# ja: 0.18
# ru: 0.272
# sw: 0.184
# te: 0.112
# th: 0.228
# zh: 0.264
# Overall Accuracy: 0.24472727272727274
